# %% [markdown]
# <a href="https://colab.research.google.com/github/erindakapllani/question_generator/blob/main/qa_pair_evaluator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymupdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 23.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 40.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

# Upload the PDF files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-42408aeb-5d7b-40e5-85e7-950fc57106fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42408aeb-5d7b-40e5-85e7-950fc57106fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    document = fitz.open(pdf_path)
    text = ""
    for page_num in range(document.page_count):
        page = document.load_page(page_num)
        text += page.get_text()
    return text

# Extract text from uploaded PDF files
pdf_texts = {}
for filename in uploaded.keys():
    pdf_texts[filename] = extract_text_from_pdf(filename)

# Combine texts from all PDFs
combined_text = "\n".join(pdf_texts.values())

# %%
for filename, text in pdf_texts.items():
    text_filename = filename.replace('.pdf', '.txt')
    with open(text_filename, 'w') as text_file:
        text_file.write(text)

# %%
import random

def get_random_chunk(text, chunk_size=1000):
    start_index = random.randint(0, len(text) - chunk_size)
    return text[start_index:start_index + chunk_size]

# Select a random chunk from the combined text
random_chunk = get_random_chunk(combined_text)

print("Random Text Chunk:")
print(random_chunk)
# Out:
# Random Text Chunk:
# ristics of future air traffic and aircraft. If the assessment reveals an unreasonable
# risk of an aircraft crash on the site, then an assessment of the associated hazards, including
# impact, fire, and explosion, shall be conducted.
# The site evaluation shall consider the potential effects on emergency plan execution, including
# effects on evacuation routes.
# July 2022
# REGDOC-1.1.1, Site Evaluation and Site Preparation for New Reactor Facilities
#
# 28
#
# 3.6.2
# Other transportation hazards
# The applicant shall evaluate present and proposed land and water transportation routes in the
# region with respect to potential collisions with SSCs, generation of explosions, chemical and
# radiological hazards, and fires.
# The site evaluation shall consider the potential effects on emergency plan execution, including
# effects on evacuation routes.
# 3.6.3
# Fires and explosions
# ...

# %%
from google.colab import files

# Upload the CSV file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ca97d486-d472-49a2-87b7-b43242795eda" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca97d486-d472-49a2-87b7-b43242795eda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Assuming the file was uploaded as qa_pairs.csv
filename = 'CNSC_qa_pairs.csv'

# Read the CSV file into a DataFrame with a specified encoding
qa_pairs = pd.read_csv(filename, encoding='latin1')  # Try 'latin1', 'iso-8859-1', or 'cp1252'

# Select a random sample of QA pairs
sample_qa_pairs = qa_pairs.sample(n=10)  # Adjust the number of samples as needed

# Display the sample QA pairs
print(sample_qa_pairs)
# Out:
#                                               Questions  \
# 654   <question>What are the record review requireme...
# 1630  <question>What information does site evaluatio...
# 1494  <question>How can climate change potentially i...
# 1472  <question>What program of investigations does ...
# 989   <question>What information should be provided ...
# 94    <question>What is included in the Radiation sa...
# 928   <question>What additional emergency procedures...
# 970   <question>Is it important to confirm that the ...
# 1893  <question>What is the purpose of the Licence A...
# 2431  <question>What sequences should be addressed i...
#
#                                                 Answers
# 654   <answer>The record review requirements include...
# 1630  <answer>The site evaluation provides input inf...
# 1494  <answer>Climate change can potentially impact ...
# 1472  <answer>The applicant needs to carry out a pro...
# 989   <answer>The licensee's name, address, and lice...
# ...
